# %% [markdown]
# ## 01 — Initial Data Understanding
#
# The purpose of this notebook is to load the original yearly datasets and inspect their structure, columns, data types and missing values.

# %%
from pathlib import Path

import numpy as np
import pandas as pd

# %%
DATA_DIR = Path("../data/raw") 
print(DATA_DIR.resolve()) ## print the absolute path
# Out:
# /mnt/data/artificial_intelligence_reviewed/data/raw

# %% [markdown]
# Ensure that the files exists and that they are in the correct position. I tried that with every year's file.

# %%
file_2025 = DATA_DIR / "2025.xlsx"

print("File path:", file_2025.resolve())
print("File exists:", file_2025.exists())
# Out:
# File path: /mnt/data/artificial_intelligence_reviewed/data/raw/2025.xlsx
# File exists: True

# %%
df_2025 = pd.read_excel(file_2025)

# %%
df_2025.head()
# Out:
#    ATP  Location              Tournament       Date  ...  AvgW  AvgL BFEW BFEL
# 0    1  Brisbane  Brisbane International 2024-12-29  ...  2.03  1.78  NaN  NaN
# 1    1  Brisbane  Brisbane International 2024-12-30  ...  1.43  2.74  NaN  NaN
# 2    1  Brisbane  Brisbane International 2024-12-30  ...  1.67  2.18  NaN  NaN
# 3    1  Brisbane  Brisbane International 2024-12-30  ...  1.59  2.36  NaN  NaN
# 4    1  Brisbane  Brisbane International 2024-12-30  ...  2.48  1.54  NaN  NaN
#
# [5 rows x 38 columns]

# %%
number_of_rows, number_of_columns = df_2025.shape

print("Number of matches:", number_of_rows)
print("Number of columns:", number_of_columns)
# Out:
# Number of matches: 2644
# Number of columns: 38

# %%
column_names = df_2025.columns.tolist()

for column in column_names: 
    print(column)
# Out:
# ATP
# Location
# Tournament
# Date
# Series
# Court
# Surface
# Round
# Best of
# Winner
# Loser
# WRank
# LRank
# WPts
# LPts
# W1
# L1
# W2
# L2
# W3
# L3
# W4
# L4
# W5
# L5
# Wsets
# Lsets
# Comment
# B365W
# B365L
# PSW
# PSL
# MaxW
# MaxL
# AvgW
# AvgL
# BFEW
# BFEL

# %%
df_2025.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2644 entries, 0 to 2643
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ATP         2644 non-null   int64
#  1   Location    2644 non-null   object
#  2   Tournament  2644 non-null   object
#  3   Date        2644 non-null   datetime64[ns]
#  4   Series      2644 non-null   object
#  5   Court       2644 non-null   object
#  6   Surface     2644 non-null   object
#  7   Round       2644 non-null   object
#  8   Best of     2644 non-null   int64
#  9   Winner      2644 non-null   object
#  10  Loser       2644 non-null   object
#  11  WRank       2644 non-null   int64
#  12  LRank       2641 non-null   float64
#  13  WPts        2644 non-null   int64
#  14  LPts        2641 non-null   float64
#  15  W1          2622 non-null   float64
#  16  L1          2622 non-null   float64
#  17  W2          2599 non-null   float64
#  18  L2          2598 non-null   float64
#  19  W3          1261 non-null   float64
#  20  L3          1261 non-null   float64
#  21  W4          268 non-null    float64
#  22  L4          268 non-null    float64
#  23  W5          100 non-null    float64
#  24  L5          100 non-null    float64
#  25  Wsets       2622 non-null   float64
#  26  Lsets       2622 non-null   float64
#  27  Comment     2644 non-null   object
#  28  B365W       2632 non-null   float64
#  29  B365L       2632 non-null   float64
#  30  PSW         2534 non-null   float64
#  31  PSL         2534 non-null   float64
#  32  MaxW        2644 non-null   float64
#  33  MaxL        2644 non-null   float64
#  34  AvgW        2644 non-null   float64
#  35  AvgL        2644 non-null   float64
#  36  BFEW        651 non-null    float64
#  37  BFEL        651 non-null    float64
# dtypes: datetime64[ns](1), float64(24), int64(4), object(9)
# memory usage: 785.1+ KB

# %%
missing_values = df_2025.isna().sum()
missing_values = missing_values.sort_values(ascending=False)

missing_values[missing_values > 0] ## select only columns with missing values
# Out:
# W5       2544
# L5       2544
# L4       2376
# W4       2376
# BFEL     1993
# BFEW     1993
# L3       1383
# W3       1383
# PSW       110
# PSL       110
# L2         46
# W2         45
# Wsets      22
# W1         22
# L1         22
# Lsets      22
# B365L      12
# B365W      12
# LRank       3
# LPts        3
# dtype: int64

# %% [markdown]
# The dataset contains a column Comment that describes whether the match was completed, retired, cancelled or otherwise unusual.

# %%
if "Comment" in df_2025.columns: 
    print(df_2025["Comment"].value_counts(dropna=False)) ## missing values are also counted
else:
    print("The Comment column is not present.")
# Out:
# Comment
# Completed    2518
# Retired       104
# Walkover       22
# Name: count, dtype: int64

# %%
years = [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]
yearly_datasets = {}

for year in years: 
    file_path = DATA_DIR / f"{year}.xlsx"
    
    print(f"Loading {file_path.name} ...")
   
    yearly_datasets[year] = pd.read_excel(file_path)
    
    n_rows, n_columns = yearly_datasets[year].shape
    print(f"{year}: {n_rows} rows and {n_columns} columns")
# Out:
# Loading 2015.xlsx ...
# /opt/pyvenv/lib/python3.13/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# 2015: 2630 rows and 40 columns
# Loading 2016.xlsx ...
# /opt/pyvenv/lib/python3.13/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# 2016: 2626 rows and 40 columns
# Loading 2017.xlsx ...
# 2017: 2633 rows and 40 columns
# Loading 2018.xlsx ...
# 2018: 2637 rows and 40 columns
# Loading 2019.xlsx ...
# 2019: 2610 rows and 36 columns
# Loading 2020.xlsx ...
# 2020: 1267 rows and 36 columns
# Loading 2021.xlsx ...
# 2021: 2489 rows and 36 columns
# Loading 2022.xlsx ...
# 2022: 2632 rows and 36 columns
# Loading 2023.xlsx ...
# 2023: 2703 rows and 36 columns
# Loading 2024.xlsx ...
# 2024: 2703 rows and 36 columns
# Loading 2025.xlsx ...
# 2025: 2644 rows and 38 columns

# %% [markdown]
# Before joining the yearly files, I checked whether they contain the same columns.
# Without checking I may unexpectedly create many missing values.
#
# set(...) is a collection of unique elements that I used to compare groups of column names.
#
# reference_columns - current_columns =
# This finds columns that are present in the 2025 dataset but missing from the current dataset.
#
# current_columns - reference_columns =
# This finds columns present in the current dataset but absent from 2025.

# %%
reference_columns = set(yearly_datasets[2025].columns)

for year, dataset in yearly_datasets.items(): 
    current_columns = set(dataset.columns)
    
    missing_compared_to_2025 = reference_columns - current_columns
    additional_compared_to_2025 = current_columns - reference_columns
    
    print(f"\nYear: {year}")
    print("Columns missing compared with 2025: ")
    print(sorted(missing_compared_to_2025))
    
    print("Additional columns compared to 2025: ")
    print(sorted(additional_compared_to_2025))
# Out:
# Year: 2015
# Columns missing compared with 2025:
# ['BFEL', 'BFEW']
# Additional columns compared to 2025:
# ['EXL', 'EXW', 'LBL', 'LBW']
#
# Year: 2016
# Columns missing compared with 2025:
# ['BFEL', 'BFEW']
# Additional columns compared to 2025:
# ['EXL', 'EXW', 'LBL', 'LBW']
#
# Year: 2017
# Columns missing compared with 2025:
# ['BFEL', 'BFEW']
# Additional columns compared to 2025:
# ['EXL', 'EXW', 'LBL', 'LBW']
#
# Year: 2018
# Columns missing compared with 2025:
# ['BFEL', 'BFEW']
# Additional columns compared to 2025:
# ['EXL', 'EXW', 'LBL', 'LBW']
#
# Year: 2019
# Columns missing compared with 2025:
# ['BFEL', 'BFEW']
# Additional columns compared to 2025:
# []
#
# Year: 2020
# Columns missing compared with 2025:
# ['BFEL', 'BFEW']
# Additional columns compared to 2025:
# []
#
# Year: 2021
# Columns missing compared with 2025:
# ['BFEL', 'BFEW']
# Additional columns compared to 2025:
# []
#
# Year: 2022
# Columns missing compared with 2025:
# ['BFEL', 'BFEW']
# Additional columns compared to 2025:
# []
#
# Year: 2023
# Columns missing compared with 2025:
# ['BFEL', 'BFEW']
# Additional columns compared to 2025:
# []
#
# Year: 2024
# Columns missing compared with 2025:
# ['BFEL', 'BFEW']
# Additional columns compared to 2025:
# []
#
# Year: 2025
# Columns missing compared with 2025:
# []
# Additional columns compared to 2025:
# []
